# %%
#Importing libraries in notebook
import pandas as pd
import numpy as np

# %%
#Importing libraries in notebook
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Importing given csv file for the Project03
df=pd.read_csv(r"C:\Users\Farhan Seraj\OneDrive\Documents\NYPD_Arrest_Data.csv")

# %%
#The first 10 rows
df.head(10)
# Out:
#    ARREST_KEY ARREST_DATE  PD_CD                         PD_DESC  KY_CD  \
# 0   261209118  01/01/2023    109        ASSAULT 2,1,UNCLASSIFIED  106.0
# 1   262984267  02/03/2023    515     CONTROLLED SUBSTANCE,SALE 3  117.0
# 2   263664549  02/15/2023    105               STRANGULATION 1ST  106.0
# 3   261345231  01/04/2023    105               STRANGULATION 1ST  106.0
# 4   263536618  02/13/2023    109        ASSAULT 2,1,UNCLASSIFIED  106.0
# 5   262030390  01/17/2023    105               STRANGULATION 1ST  106.0
# 6   262362214  01/23/2023    105               STRANGULATION 1ST  106.0
# 7   264579718  03/04/2023    153                          RAPE 3  104.0
# 8   262500981  01/25/2023    729  FORGERY,ETC.,UNCLASSIFIED-FELO  113.0
# 9   265281035  03/17/2023    244   BURGLARY,UNCLASSIFIED,UNKNOWN  107.0
#
#          OFNS_DESC    LAW_CODE LAW_CAT_CD ARREST_BORO  ARREST_PRECINCT  \
# 0   FELONY ASSAULT  PL 1200501          F           K               77
# ...

# %%
#The last 10 rows
df.tail(10)
# Out:
#         ARREST_KEY ARREST_DATE  PD_CD                         PD_DESC  KY_CD  \
# 170085   273821910  09/02/2023    101                       ASSAULT 3  344.0
# 170086   271871799  07/25/2023    969  TRAFFIC,UNCLASSIFIED INFRACTIO  881.0
# 170087   273466659  08/26/2023    922  TRAFFIC,UNCLASSIFIED MISDEMEAN  348.0
# 170088   269968287  06/16/2023    478  THEFT OF SERVICES, UNCLASSIFIE  343.0
# 170089   270409968  06/26/2023    339  LARCENY,PETIT FROM OPEN AREAS,  341.0
# 170090   270955727  07/07/2023    397  ROBBERY,OPEN AREA UNCLASSIFIED  105.0
# 170091   273117887  08/18/2023    681      CHILD, ENDANGERING WELFARE  233.0
# 170092   274301006  09/13/2023    969  TRAFFIC,UNCLASSIFIED INFRACTIO  881.0
# 170093   269912233  06/15/2023    490    STOLEN PROPERTY 3,POSSESSION  232.0
# 170094   272045762  07/28/2023    729  FORGERY,ETC.,UNCLASSIFIED-FELO  113.0
#
#                              OFNS_DESC    LAW_CODE LAW_CAT_CD ARREST_BORO  \
# ...

# %%
#The summary description of the data
df.describe()
# Out:
#          ARREST_KEY          PD_CD          KY_CD  ARREST_PRECINCT  \
# count  1.700950e+05  170095.000000  170082.000000    170095.000000
# mean   2.683705e+08     425.242200     249.766342        63.423569
# std    4.027782e+06     275.312255     148.500439        34.596068
# min    2.611809e+08       2.000000     101.000000         1.000000
# 25%    2.649555e+08     114.000000     113.000000        40.000000
# 50%    2.685036e+08     397.000000     236.000000        62.000000
# 75%    2.718261e+08     705.000000     344.000000       101.000000
# max    2.752350e+08     997.000000     995.000000       123.000000
#
#        JURISDICTION_CODE    X_COORD_CD     Y_COORD_CD       Latitude  \
# count      170095.000000  1.700950e+05  170095.000000  170095.000000
# mean            0.945918  1.005863e+06  208326.176925      40.738196
# std             7.683909  2.152952e+04   29737.941320       0.128134
# min             0.000000  0.000000e+00       0.000000       0.000000
# ...

# %%
#The shape of the data
df.shape
# Out:
# (170095, 19)

# %%
#The information of the data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 170095 entries, 0 to 170094
# Data columns (total 19 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   ARREST_KEY                170095 non-null  int64
#  1   ARREST_DATE               170095 non-null  object
#  2   PD_CD                     170095 non-null  int64
#  3   PD_DESC                   170095 non-null  object
#  4   KY_CD                     170082 non-null  float64
#  5   OFNS_DESC                 170095 non-null  object
#  6   LAW_CODE                  170095 non-null  object
#  7   LAW_CAT_CD                168838 non-null  object
#  8   ARREST_BORO               170095 non-null  object
#  9   ARREST_PRECINCT           170095 non-null  int64
#  10  JURISDICTION_CODE         170095 non-null  int64
#  11  AGE_GROUP                 170095 non-null  object
#  12  PERP_SEX                  170095 non-null  object
# ...

# %%
#The sum of isna of the data frame
df.isna().sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of         ARREST_KEY  ARREST_DATE  PD_CD  PD_DESC  KY_CD  OFNS_DESC  LAW_CODE  \
# 0            False        False  False    False  False      False     False
# 1            False        False  False    False  False      False     False
# 2            False        False  False    False  False      False     False
# 3            False        False  False    False  False      False     False
# 4            False        False  False    False  False      False     False
# ...            ...          ...    ...      ...    ...        ...       ...
# 170090       False        False  False    False  False      False     False
# 170091       False        False  False    False  False      False     False
# 170092       False        False  False    False  False      False     False
# 170093       False        False  False    False  False      False     False
# ...

# %%
#The variable name and types
df.dtypes
# Out:
# ARREST_KEY                    int64
# ARREST_DATE                  object
# PD_CD                         int64
# PD_DESC                      object
# KY_CD                       float64
# OFNS_DESC                    object
# LAW_CODE                     object
# LAW_CAT_CD                   object
# ARREST_BORO                  object
# ARREST_PRECINCT               int64
# JURISDICTION_CODE             int64
# AGE_GROUP                    object
# PERP_SEX                     object
# PERP_RACE                    object
# X_COORD_CD                    int64
# Y_COORD_CD                    int64
# Latitude                    float64
# Longitude                   float64
# New Georeferenced Column     object
# dtype: object

# %%
#Percentage of missing values in variables
(df.isna().sum()/df.shape[0]*100).sort_values(ascending=False)
# Out:
# LAW_CAT_CD                  0.738999
# KY_CD                       0.007643
# ARREST_KEY                  0.000000
# AGE_GROUP                   0.000000
# Longitude                   0.000000
# Latitude                    0.000000
# Y_COORD_CD                  0.000000
# X_COORD_CD                  0.000000
# PERP_RACE                   0.000000
# PERP_SEX                    0.000000
# ARREST_PRECINCT             0.000000
# JURISDICTION_CODE           0.000000
# ARREST_DATE                 0.000000
# ARREST_BORO                 0.000000
# LAW_CODE                    0.000000
# OFNS_DESC                   0.000000
# PD_DESC                     0.000000
# PD_CD                       0.000000
# New Georeferenced Column    0.000000
# dtype: float64

# %%
#Types of crimes
df.OFNS_DESC.unique()
# Out:
# array(['FELONY ASSAULT', 'DANGEROUS DRUGS', 'RAPE', 'FORGERY', 'BURGLARY',
#        'ARSON', 'ASSAULT 3 & RELATED OFFENSES', 'ROBBERY',
#        'PETIT LARCENY', 'DANGEROUS WEAPONS', 'MISCELLANEOUS PENAL LAW',
#        'HARRASSMENT 2', 'OFF. AGNST PUB ORD SENSBLTY &', 'JOSTLING',
#        'SEX CRIMES', '(null)', 'FRAUDS', 'ESCAPE 3', "BURGLAR'S TOOLS",
#        'VEHICLE AND TRAFFIC LAWS', 'OFFENSES AGAINST THE PERSON',
#        'OFFENSES INVOLVING FRAUD', 'INTOXICATED & IMPAIRED DRIVING',
#        'FOR OTHER AUTHORITIES', 'OTHER OFFENSES RELATED TO THEF',
#        'POSSESSION OF STOLEN PROPERTY', 'OTHER TRAFFIC INFRACTION',
#        'GRAND LARCENY', 'CRIMINAL MISCHIEF & RELATED OF',
#        'OTHER STATE LAWS (NON PENAL LA',
#        'PROSTITUTION & RELATED OFFENSES', 'GAMBLING', 'CRIMINAL TRESPASS',
#        'OFFENSES AGAINST PUBLIC ADMINI', 'MURDER & NON-NEGL. MANSLAUGHTE',
#        'OTHER STATE LAWS', 'CANNABIS RELATED OFFENSES',
# ...

# %%
#Top 10 crime types
df.OFNS_DESC.value_counts().iloc[:10]
# Out:
# OFNS_DESC
# ASSAULT 3 & RELATED OFFENSES      25200
# PETIT LARCENY                     18025
# FELONY ASSAULT                    16030
# DANGEROUS DRUGS                   11526
# MISCELLANEOUS PENAL LAW           11132
# VEHICLE AND TRAFFIC LAWS           9442
# CRIMINAL MISCHIEF & RELATED OF     8333
# ROBBERY                            8169
# GRAND LARCENY                      7901
# DANGEROUS WEAPONS                  7245
# Name: count, dtype: int64

# %%
#Top 10 types of crime shown visually
df.OFNS_DESC.value_counts().iloc[:10].sort_values().plot(kind="barh", title = "Types of Crimes")
# Out:
# <Axes: title={'center': 'Types of Crimes'}, ylabel='OFNS_DESC'>

# %%
#Specific crime analysis
df1 = df[df.OFNS_DESC.str.contains('FELONY ASSAULT')]
df1.head()
# Out:
#    ARREST_KEY ARREST_DATE  PD_CD                   PD_DESC  KY_CD  \
# 0   261209118  01/01/2023    109  ASSAULT 2,1,UNCLASSIFIED  106.0
# 2   263664549  02/15/2023    105         STRANGULATION 1ST  106.0
# 3   261345231  01/04/2023    105         STRANGULATION 1ST  106.0
# 4   263536618  02/13/2023    109  ASSAULT 2,1,UNCLASSIFIED  106.0
# 5   262030390  01/17/2023    105         STRANGULATION 1ST  106.0
#
#         OFNS_DESC    LAW_CODE LAW_CAT_CD ARREST_BORO  ARREST_PRECINCT  \
# 0  FELONY ASSAULT  PL 1200501          F           K               77
# 2  FELONY ASSAULT  PL 1211200          F           K               62
# 3  FELONY ASSAULT  PL 1211200          F           M               32
# 4  FELONY ASSAULT  PL 12005WX          F           K               71
# 5  FELONY ASSAULT  PL 1211200          F           Q              113
#
#    JURISDICTION_CODE AGE_GROUP PERP_SEX PERP_RACE  X_COORD_CD  Y_COORD_CD  \
# ...

# %%
#Shape of the specific crime
df1.shape
# Out:
# (16030, 19)

# %%
#Description of the specific crime
df1.describe
# Out:
# <bound method NDFrame.describe of         ARREST_KEY ARREST_DATE  PD_CD                       PD_DESC  KY_CD  \
# 0        261209118  01/01/2023    109      ASSAULT 2,1,UNCLASSIFIED  106.0
# 2        263664549  02/15/2023    105             STRANGULATION 1ST  106.0
# 3        261345231  01/04/2023    105             STRANGULATION 1ST  106.0
# 4        263536618  02/13/2023    109      ASSAULT 2,1,UNCLASSIFIED  106.0
# 5        262030390  01/17/2023    105             STRANGULATION 1ST  106.0
# ...            ...         ...    ...                           ...    ...
# 169998   274876735  09/24/2023    106  ASSAULT POLICE/PEACE OFFICER  106.0
# 170030   270817570  07/05/2023    109      ASSAULT 2,1,UNCLASSIFIED  106.0
# 170034   270998821  07/08/2023    109      ASSAULT 2,1,UNCLASSIFIED  106.0
# 170044   272116815  07/30/2023    109      ASSAULT 2,1,UNCLASSIFIED  106.0
# 170077   270992600  07/08/2023    109      ASSAULT 2,1,UNCLASSIFIED  106.0
#
# ...

# %%
#Specific crime vizualization by gender

df1['PERP_SEX'].value_counts().iloc[:3].plot(kind="bar", title = 'Felony Assault Perps by Gender', rot=0)
# Out:
# <Axes: title={'center': 'Felony Assault Perps by Gender'}, xlabel='PERP_SEX'>

# %%
df1['PERP_RACE'].value_counts().iloc[:7].plot(kind="barh", title = 'Felony Assault Perps by Race')
# Out:
# <Axes: title={'center': 'Felony Assault Perps by Race'}, ylabel='PERP_RACE'>

# %%
#Specific crime analysis02
df2 = df[df.OFNS_DESC.str.contains('BURGLARY')]
df2.head()
# Out:
#     ARREST_KEY ARREST_DATE  PD_CD                        PD_DESC  KY_CD  \
# 9    265281035  03/17/2023    244  BURGLARY,UNCLASSIFIED,UNKNOWN  107.0
# 38   267754535  05/05/2023    244  BURGLARY,UNCLASSIFIED,UNKNOWN  107.0
# 56   273583997  08/29/2023    244  BURGLARY,UNCLASSIFIED,UNKNOWN  107.0
# 72   265091957  03/14/2023    244  BURGLARY,UNCLASSIFIED,UNKNOWN  107.0
# 99   273601216  08/29/2023    244  BURGLARY,UNCLASSIFIED,UNKNOWN  107.0
#
#    OFNS_DESC    LAW_CODE LAW_CAT_CD ARREST_BORO  ARREST_PRECINCT  \
# 9   BURGLARY  PL 1402501          F           M               24
# 38  BURGLARY  PL 1402000          F           M               10
# 56  BURGLARY  PL 1402000          F           Q              101
# 72  BURGLARY  PL 1402501          F           K               84
# 99  BURGLARY  PL 1402000          F           K               78
#
#     JURISDICTION_CODE AGE_GROUP PERP_SEX PERP_RACE  X_COORD_CD  Y_COORD_CD  \
# ...

# %%
#Shape of the specific crime
df2.shape
# Out:
# (4753, 19)

# %%
#Description of the specific crime
df2.describe
# Out:
# <bound method NDFrame.describe of         ARREST_KEY ARREST_DATE  PD_CD                        PD_DESC  KY_CD  \
# 9        265281035  03/17/2023    244  BURGLARY,UNCLASSIFIED,UNKNOWN  107.0
# 38       267754535  05/05/2023    244  BURGLARY,UNCLASSIFIED,UNKNOWN  107.0
# 56       273583997  08/29/2023    244  BURGLARY,UNCLASSIFIED,UNKNOWN  107.0
# 72       265091957  03/14/2023    244  BURGLARY,UNCLASSIFIED,UNKNOWN  107.0
# 99       273601216  08/29/2023    244  BURGLARY,UNCLASSIFIED,UNKNOWN  107.0
# ...            ...         ...    ...                            ...    ...
# 170024   272836135  08/14/2023    244  BURGLARY,UNCLASSIFIED,UNKNOWN  107.0
# 170029   271826048  07/25/2023    244  BURGLARY,UNCLASSIFIED,UNKNOWN  107.0
# 170040   273071455  08/17/2023    244  BURGLARY,UNCLASSIFIED,UNKNOWN  107.0
# 170055   271228946  07/13/2023    244  BURGLARY,UNCLASSIFIED,UNKNOWN  107.0
# 170060   275002624  09/27/2023    244  BURGLARY,UNCLASSIFIED,UNKNOWN  107.0
#
# ...

# %%
#Specific crime vizualization by gender

df2['PERP_SEX'].value_counts().iloc[:3].plot(kind="bar", title = 'Burglary Perps by Gender', rot=0)
# Out:
# <Axes: title={'center': 'Burglary Perps by Gender'}, xlabel='PERP_SEX'>

# %%
df2['PERP_RACE'].value_counts().iloc[:7].plot(kind="barh", title = 'Burglary Perps by Race')
# Out:
# <Axes: title={'center': 'Burglary Perps by Race'}, ylabel='PERP_RACE'>

# %%
#Total number of crimes in each borough
df['ARREST_BORO'].value_counts().sort_values().plot(kind="barh", title = 'Total of Crime Events by Borough')
# Out:
# <Axes: title={'center': 'Total of Crime Events by Borough'}, ylabel='ARREST_BORO'>
